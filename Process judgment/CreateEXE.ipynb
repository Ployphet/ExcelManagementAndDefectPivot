# %%
pip install --upgrade openpyxl --trusted-host pypi.org --trusted-host files.pythonhosted.org

# %%
# !pyinstaller --onefile --windowed --hidden-import=openpyxl.cell._writer --icon=BridgestoneICO.ico --name="Process Judging Information" Process_Judging_Apps.py
# Out:
# 22731 INFO: PyInstaller: 6.12.0, contrib hooks: 2025.2
# 22731 INFO: Python: 3.11.7 (conda)
# 22772 INFO: Platform: Windows-10-10.0.22621-SP0
# 22772 INFO: Python environment: C:\Users\Ployphet.veerasak\AppData\Local\anaconda3
# 22774 INFO: wrote C:\Users\Ployphet.veerasak\Desktop\Python project\Process judging information\Process Judging Information\file\Process Judging Information.spec
# 22811 INFO: Module search paths (PYTHONPATH):
# ['C:\\Users\\Ployphet.veerasak\\AppData\\Local\\anaconda3\\Scripts\\pyinstaller.exe',
#  'C:\\Users\\Ployphet.veerasak\\AppData\\Local\\anaconda3\\python311.zip',
#  'C:\\Users\\Ployphet.veerasak\\AppData\\Local\\anaconda3\\DLLs',
#  'C:\\Users\\Ployphet.veerasak\\AppData\\Local\\anaconda3\\Lib',
#  'C:\\Users\\Ployphet.veerasak\\AppData\\Local\\anaconda3',
#  'C:\\Users\\Ployphet.veerasak\\AppData\\Local\\anaconda3\\Lib\\site-packages',
#  'C:\\Users\\Ployphet.veerasak\\AppData\\Local\\anaconda3\\Lib\\site-packages\\win32',
# ...

# %%
#!pyinstaller --onefile --windowed --icon=BridgestoneICO.ico --name="Process Judging Information" Process_Judging_Apps.py
