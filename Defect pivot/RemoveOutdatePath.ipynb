# %%
# !conda config --set ssl_verify no

# %%
# !conda remove --yes pathlib
# Out:
# Channels:
#  - defaults
# Platform: win-64
# ...
# Solving environment: ...working... done
#
# ## Package Plan ##
#
#   environment location: C:\Users\Ployphet.veerasak\AppData\Local\anaconda3
#
#   removed specs:
#     - pathlib
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     conda-repo-cli-1.0.88      |  py311haa95532_0         200 KB
#     ------------------------------------------------------------
#                                            Total:         200 KB
#
# The following packages will be REMOVED:
#
#   pathlib-1.0.1-pyhd3eb1b0_1
#
# The following packages will be UPDATED:
#
#   conda-repo-cli                     1.0.75-py311haa95532_0 --> 1.0.88-py311haa95532_0
#
#
#
# ...
# Preparing transaction: ...working... done
# Verifying transaction: ...working... done
# Executing transaction: ...working... done

# %%
# !pyinstaller --onefile --windowed ActivateScript.py
# Out:
# 14890 INFO: PyInstaller: 6.12.0, contrib hooks: 2025.2
# 14896 INFO: Python: 3.11.7 (conda)
# 14923 INFO: Platform: Windows-10-10.0.22621-SP0
# 14923 INFO: Python environment: C:\Users\Ployphet.veerasak\AppData\Local\anaconda3
# 14923 INFO: wrote C:\Users\Ployphet.veerasak\Desktop\Defect\Liner air\ActivateScript.spec
# 14947 INFO: Module search paths (PYTHONPATH):
# ['C:\\Users\\Ployphet.veerasak\\AppData\\Local\\anaconda3\\Scripts\\pyinstaller.exe',
#  'C:\\Users\\Ployphet.veerasak\\AppData\\Local\\anaconda3\\python311.zip',
#  'C:\\Users\\Ployphet.veerasak\\AppData\\Local\\anaconda3\\DLLs',
#  'C:\\Users\\Ployphet.veerasak\\AppData\\Local\\anaconda3\\Lib',
#  'C:\\Users\\Ployphet.veerasak\\AppData\\Local\\anaconda3',
#  'C:\\Users\\Ployphet.veerasak\\AppData\\Local\\anaconda3\\Lib\\site-packages',
#  'C:\\Users\\Ployphet.veerasak\\AppData\\Local\\anaconda3\\Lib\\site-packages\\win32',
#  'C:\\Users\\Ployphet.veerasak\\AppData\\Local\\anaconda3\\Lib\\site-packages\\win32\\lib',
# ...
